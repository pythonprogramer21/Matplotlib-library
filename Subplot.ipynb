# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
plt.subplot(2,2,1)
plt.pie([20])
plt.subplot(2,2,2)
plt.pie([20,90])
plt.subplot(2,2,3)
plt.pie([20,37,87])
plt.subplot(2,2,4)
plt.pie([20,56,90,23])
plt.show()

# %%
plt.subplot(3,2,1)
plt.subplot(3,2,2)
plt.subplot(3,2,3)
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,2,1)
plt.subplot(3,2,2)
plt.subplot(3,2,3)
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)
plt.show()

# %%
month=["may","April","March","june","juley"]
temp=[56,76,23,19,30]
temp1=[17,89,65,34,67]
plt.figure(figsize=(12,8))
plt.subplot(3,2,1)
plt.plot(month,temp,color="r",linestyle="--",label="temp2020")
plt.plot(month,temp1,color="y",linestyle="-.",label="tem2021")
plt.title("Delhi temperature")
plt.xlabel("Months")
plt.ylabel("Temperature")
plt.legend(loc=1)
plt.subplot(3,2,2)

plt.subplot(3,2,3)
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)
plt.show()

# %%
month=["may","April","March","june","juley"]
temp=[56,76,23,19,30]
temp1=[17,89,65,34,67]
plt.figure(figsize=(12,8))
plt.subplot(3,2,1)
plt.plot(month,temp,color="r",linestyle="-.",label="tem2021")
plt.plot(month,temp1,color="y",linestyle="-.",label="tem2021")
plt.title("Delhi temperature")
plt.xlabel("Months")
plt.ylabel("Temperature")
plt.legend(loc=1)
plt.subplot(3,2,2)
mlst=np.random.randint(18,45,(20))
plst=np.random.randint(15,40,(30))
bins=[15,20,30,45]
plt.hist([plst,mlst],bins,rwidth=0.7,color=['y','m'],label=['PL','ML'])
plt.title('pL student')
plt.legend(loc=1)
plt.subplot(3,2,3)
k=pd.read_csv('F:\\suryakant notes\\pra1.csv')
x=k['Profit']
y=k['Rate']
plt.scatter(x,y)
plt.title('Copany data')
plt.xlabel('Profit')
plt.ylabel('Rate')
plt.show()
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)
plt.show()

# %%
month=["may","April","March","june","juley"]
temp=[56,76,23,19,30]
temp1=[17,89,65,34,67]
plt.figure(figsize=(16,9))
plt.subplot(3,2,1)
plt.plot(month,temp,color="r",linestyle="-.",label="tem2021")
plt.plot(month,temp1,color="y",linestyle="-.",label="tem2021")
plt.title("Delhi temperature")
plt.xlabel("Months")
plt.ylabel("Temperature")
plt.legend(loc=1)
plt.subplot(3,2,2)
mlst=np.random.randint(18,45,(20))
plst=np.random.randint(15,40,(30))
bins=[15,20,30,45]
plt.hist([plst,mlst],bins,rwidth=0.7,color=['y','m'],label=['PL','ML'])
plt.title('pL student')
plt.legend(loc=1)
plt.subplot(3,2,3)
k=pd.read_csv('F:\\suryakant notes\\pra1.csv')
x=k['Profit']
y=k['Rate']
plt.scatter(x,y)
plt.title('Copany data')
plt.xlabel('Profit')
plt.ylabel('Rate')
plt.show()
plt.subplot(3,2,4)
cla=['Python','R','AI','ML','DS']
cla1st=[30,10,20,25,10]
cla2st=[40,5,20,20,10]
cla3st=[35,5,30,15,15]
cla_in=np.arange(len(cla))
width=0.2
plt.bar(cla_in,cla1st,width,color='b',label='Class 1')
plt.bar(cla_in+width,cla2st,width,color='g',label='Class ')
plt.bar(cla_in+width+width,cla3st,width,color='y',label='Class 1')
plt.xticks(cla_in+width,cla)
plt.title('This is student info')
plt.xlabel('Courses')
plt.ylabel('Student Size')
plt.legend(loc=1)
plt.show()
plt.subplot(3,2,5)
cla=['Python','R','Machine Learning','Artificial intelligence','Data Science']
cla1st=[46,78,30,43,28]
plt.pie(cla1st)
plt.show()
plt.subplot(3,2,6,projection="polar")
plt.show()

# %%
month=["may","April","March","june","juley"]
temp=[56,76,23,19,30]
temp1=[17,89,65,34,67]
plt.figure(figsize=(16,9))
plt.subplot(3,2,1)
plt.plot(month,temp,color="r",linestyle="-.",label="tem2021")
plt.plot(month,temp1,color="y",linestyle="-.",label="tem2021")
plt.title("Delhi temperature")
plt.xlabel("Months")
plt.ylabel("Temperature")
plt.legend(loc=1)
plt.subplot(3,2,2)
mlst=np.random.randint(18,45,(20))
plst=np.random.randint(15,40,(30))
bins=[15,20,30,45]
plt.hist([plst,mlst],bins,rwidth=0.7,color=['y','m'],label=['PL','ML'])
plt.title('pL student')
plt.legend(loc=1)
plt.subplot(3,2,3)
k=pd.read_csv('F:\\suryakant notes\\pra1.csv')
x=k['Profit']
y=k['Rate']
plt.scatter(x,y)
plt.title('Copany data')
plt.xlabel('Profit')
plt.ylabel('Rate')
plt.show()
plt.subplot(3,2,4)
cla=['Python','R','AI','ML','DS']
cla1st=[30,10,20,25,10]
cla2st=[40,5,20,20,10]
cla3st=[35,5,30,15,15]
cla_in=np.arange(len(cla))
width=0.2
plt.bar(cla_in,cla1st,width,color='b',label='Class 1')
plt.bar(cla_in+width,cla2st,width,color='g',label='Class ')
plt.bar(cla_in+width+width,cla3st,width,color='y',label='Class 1')
plt.xticks(cla_in+width,cla)
plt.title('This is student info')
plt.xlabel('Courses')
plt.ylabel('Student Size')
plt.legend(loc=1)
plt.show()
plt.subplot(3,2,5)
cla=['Python','R','Machine Learning','Artificial intelligence','Data Science']
cla1st=[46,78,30,43,28]
plt.pie(cla1st)
plt.show()
plt.subplot(3,2,6,projection="polar",facecolor="k")
plt.show()

# %%
month=["may","April","March","june","juley"]
temp=[56,76,23,19,30]
temp1=[17,89,65,34,67]
plt.figure(figsize=(16,9))
plt.subplot(3,2,1)
plt.plot(month,temp,color="r",linestyle="-.",label="tem2021")
plt.plot(month,temp1,color="y",linestyle="-.",label="tem2021")
plt.title("Delhi temperature")
plt.xlabel("Months")
plt.ylabel("Temperature")
plt.legend(loc=1)
plt.subplot(3,2,2)
mlst=np.random.randint(18,45,(20))
plst=np.random.randint(15,40,(30))
bins=[15,20,30,45]
plt.hist([plst,mlst],bins,rwidth=0.7,color=['y','m'],label=['PL','ML'])
plt.title('pL student')
plt.legend(loc=1)
plt.subplot(3,2,3)
k=pd.read_csv('F:\\suryakant notes\\pra1.csv')
x=k['Profit']
y=k['Rate']
plt.scatter(x,y)
plt.title('Copany data')
plt.xlabel('Profit')
plt.ylabel('Rate')
plt.show()
plt.subplot(3,2,4)
cla=['Python','R','AI','ML','DS']
cla1st=[30,10,20,25,10]
cla2st=[40,5,20,20,10]
cla3st=[35,5,30,15,15]
cla_in=np.arange(len(cla))
width=0.2
plt.bar(cla_in,cla1st,width,color='b',label='Class 1')
plt.bar(cla_in+width,cla2st,width,color='g',label='Class ')
plt.bar(cla_in+width+width,cla3st,width,color='y',label='Class 1')
plt.xticks(cla_in+width,cla)
plt.title('This is student info')
plt.xlabel('Courses')
plt.ylabel('Student Size')
plt.legend(loc=1)
plt.show()
plt.subplot(3,2,5)
cla=['Python','R','Machine Learning','Artificial intelligence','Data Science']
cla1st=[46,78,30,43,28]
plt.pie(cla1st)
plt.show()
plt.subplot(3,2,6,projection="polar")
plt.show()
